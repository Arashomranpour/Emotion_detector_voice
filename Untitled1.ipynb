# %%
! pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-294f6e71-33ce-4e82-b9e3-1d45b6a44d71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-294f6e71-33ce-4e82-b9e3-1d45b6a44d71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                         title                                        size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  ------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# hummaamqaasim/jobs-in-data                                  Jobs and Salaries in Data Science            76KB  2023-12-25 20:03:32           5364         95  1.0
# thedrcat/daigt-v2-train-dataset                             DAIGT V2 Train Dataset                       29MB  2023-11-16 01:38:36           4108        317  1.0
# chandanchoudhury/world-population-dataset                   World Population Dataset                     77KB  2024-01-06 05:26:23            758         24  1.0
# ...

# %%
# !kaggle datasets download -d ejlok1/toronto-emotional-speech-set-tess
# Out:
# ...
#  97% 417M/428M [00:05<00:00, 53.1MB/s]
# 100% 428M/428M [00:05<00:00, 78.5MB/s]

# %%
! mkdir train

# %%
! unzip toronto-emotional-speech-set-tess.zip -d train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_back_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_bar_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_base_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_bath_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_bean_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_beg_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_bite_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_boat_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_bone_angry.wav
#   inflating: train/TESS Toronto emotional speech set data/OAF_angry/OAF_book_angry.wav
# ...

# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings("ignore")

# %%
# df=pd.read_csv("./")
path=[]
lbls=[]
for dirname,_,filenames in os.walk("./train/TESS Toronto emotional speech set data"):
  for filename in filenames:
    path.append(os.path.join(dirname,filename))
    print("file", filename)

    label=filename.split("_")[-1]
    label=label.split(".")[0]
    # print("label" , label)
    lbls.append(label.lower())
# Out:
# file YAF_loaf_sad.wav
# file YAF_tough_sad.wav
# file YAF_vote_sad.wav
# file YAF_far_sad.wav
# file YAF_base_sad.wav
# file YAF_which_sad.wav
# file YAF_dip_sad.wav
# file YAF_have_sad.wav
# file YAF_pike_sad.wav
# file YAF_jug_sad.wav
# file YAF_food_sad.wav
# file YAF_such_sad.wav
# file YAF_tire_sad.wav
# file YAF_mood_sad.wav
# file YAF_whip_sad.wav
# file YAF_gap_sad.wav
# file YAF_thumb_sad.wav
# file YAF_take_sad.wav
# file YAF_shout_sad.wav
# file YAF_make_sad.wav
# file YAF_lean_sad.wav
# file YAF_germ_sad.wav
# file YAF_puff_sad.wav
# file YAF_cool_sad.wav
# file YAF_hash_sad.wav
# file YAF_keg_sad.wav
# file YAF_rot_sad.wav
# file YAF_hall_sad.wav
# file YAF_pain_sad.wav
# file YAF_juice_sad.wav
# file YAF_thought_sad.wav
# file YAF_vine_sad.wav
# file YAF_knock_sad.wav
# file YAF_wheat_sad.wav
# file YAF_pick_sad.wav
# file YAF_hurl_sad.wav
# file YAF_walk_sad.wav
# file YAF_good_sad.wav
# file YAF_bath_sad.wav
# file YAF_lore_sad.wav
# file YAF_mouse_sad.wav
# ...

# %%
path[:3]
# Out:
# ['./train/TESS Toronto emotional speech set data/YAF_sad/YAF_loaf_sad.wav',
#  './train/TESS Toronto emotional speech set data/YAF_sad/YAF_tough_sad.wav',
#  './train/TESS Toronto emotional speech set data/YAF_sad/YAF_vote_sad.wav']

# %%
lbls[:3]
# Out:
# ['sad', 'sad', 'sad']

# %%
df=pd.DataFrame()
df["speech"]=path
df["label"]=lbls
df.head()
# Out:
#                                               speech label
# 0  ./train/TESS Toronto emotional speech set data...   sad
# 1  ./train/TESS Toronto emotional speech set data...   sad
# 2  ./train/TESS Toronto emotional speech set data...   sad
# 3  ./train/TESS Toronto emotional speech set data...   sad
# 4  ./train/TESS Toronto emotional speech set data...   sad

# %%
df["label"].value_counts()
# Out:
# sad        400
# disgust    400
# happy      400
# neutral    400
# angry      400
# ps         400
# fear       400
# Name: label, dtype: int64

# %% [markdown]
# EDA

# %%
sns.histplot(df["label"])
# Out:
# <Axes: xlabel='label', ylabel='Count'>

# %%
# !pip install librosa

# %%
def waveplt(data,sample,emotion):
  plt.figure(figsize=(10,4))
  plt.title(emotion)
  librosa.display.waveshow(data,sr=sample)
  plt.show()

def specto(data,sample,emotion):
  x=librosa.stft(data)
  x_db=librosa.amplitude_to_db(abs(x))
  plt.figure(figsize=(11,4))
  plt.title(emotion)
  librosa.display.specshow(x_db,sr=sample,x_axis="time",y_axis="hz")
  plt.colorbar()

# %%
pathh=df["speech"][df["label"]=="fear"].iloc[200]
# pathh
data,sampling_rate=librosa.load(pathh)
waveplt(data,sampling_rate,"fear")
specto(data,sampling_rate,"fear")
Audio(pathh)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pathh=df["speech"][df["label"]=="sad"].iloc[200]
# pathh
data,sampling_rate=librosa.load(pathh)
waveplt(data,sampling_rate,"sad")
specto(data,sampling_rate,"sad")
Audio(pathh)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emot="disgust"

pathh=df["speech"][df["label"]==emot].iloc[200]
# pathh
data,sampling_rate=librosa.load(pathh)
waveplt(data,sampling_rate,emot)
specto(data,sampling_rate,emot)
Audio(pathh)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emot="ps"

pathh=df["speech"][df["label"]==emot].iloc[200]
# pathh
data,sampling_rate=librosa.load(pathh)
waveplt(data,sampling_rate,emot)
specto(data,sampling_rate,emot)
Audio(pathh)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Feature Extraction

# %%
def extraxt(filename):
  y,sr=librosa.load(filename,duration=3,offset=0.5)
  mfcc=np.mean(librosa.feature.mfcc(y=y,sr=sr,n_mfcc=40).T,axis=0)
  return mfcc

# %%
extraxt(df["speech"][10])
# Out:
# array([-421.77957  ,   81.3005   ,   28.309994 ,   36.949852 ,
#           9.601727 ,   10.33821  ,    2.682823 ,  -15.907814 ,
#           1.6420516,   -8.784454 ,   -5.6462426,   -0.5014355,
#          -8.704105 ,   12.235167 ,   -6.075576 ,   -4.1605067,
#           2.2828653,   -1.2206118,   -6.4095273,   -5.7069073,
#          -6.994109 ,   -5.906503 ,   -7.238301 ,    4.881203 ,
#          -1.8731697,    5.834687 ,    2.1528034,   -2.8788736,
#          -2.5588512,    2.0711234,    1.5190548,   16.913342 ,
#           5.5119414,    9.865197 ,    1.2700102,    2.0602145,
#           6.548618 ,   10.232173 ,    7.853645 ,    8.240214 ],
#       dtype=float32)

# %%
len(extraxt(df["speech"][10]))
# Out:
# 40

# %%
X_mfcc=df["speech"].apply(lambda x : extraxt(x))

# %%
X_mfcc

# %%
X=[x for x in X_mfcc]
X=np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
x=np.expand_dims(X,-1)
x.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
one=OneHotEncoder()
y=one.fit_transform(df[["label"]])

# %%
y=y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, SimpleRNN
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping


model = Sequential([

    LSTM(256, return_sequences=True,input_shape=(40,1)),
    LSTM(128, return_sequences=True),
    SimpleRNN(25,activation="relu"),
    BatchNormalization(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.1),
    Dense(7, activation="softmax")
])


model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])

# Early stopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=40, restore_best_weights=True)


# Training the model
history = model.fit(X, y, epochs=150, batch_size=200, validation_split=0.2, callbacks=[early_stopping],shuffle=True)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 8s 177ms/step - loss: 1.7628 - accuracy: 0.3009 - val_loss: 2.3368 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 12/12 [==============================] - 1s 58ms/step - loss: 1.3905 - accuracy: 0.4982 - val_loss: 2.9765 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 12/12 [==============================] - 1s 55ms/step - loss: 1.1080 - accuracy: 0.5656 - val_loss: 3.4795 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 12/12 [==============================] - 1s 53ms/step - loss: 0.8713 - accuracy: 0.6826 - val_loss: 3.6851 - val_accuracy: 0.2036
# Epoch 5/150
# 12/12 [==============================] - 1s 52ms/step - loss: 0.6222 - accuracy: 0.7933 - val_loss: 3.2546 - val_accuracy: 0.2804
# Epoch 6/150
# 12/12 [==============================] - 1s 50ms/step - loss: 0.4249 - accuracy: 0.8589 - val_loss: 4.0106 - val_accuracy: 0.2911
# Epoch 7/150
# ...

# %%
# from keras.models import Sequential
# from keras.layers import LSTM,Dense,Dropout,BatchNormalization
# model=Sequential([
#     LSTM(256,return_sequences=True,input_shape=(40,1)),
#     LSTM(128,return_sequences=False),
#     Dense(128,activation="relu"),
#     Dropout(0.2),
#     Dense(64,activation="relu"),
#     Dropout(0.2),
#     Dense(32,activation="relu"),
#     Dropout(0.2),
#     BatchNormalization(),
#     Dense(7,activation="softmax")
# ])

# model.compile("adam",loss="categorical_crossentropy",metrics=["accuracy"])
# model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_2 (LSTM)               (None, 40, 256)           264192
#
#  lstm_3 (LSTM)               (None, 128)               197120
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dense_10 (Dense)            (None, 7)                 231
#
# ...
# Total params: 488519 (1.86 MB)
# Trainable params: 488455 (1.86 MB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________

# %%
# epochs=list(range(150))
plt.plot(history.history["accuracy"],label="Train",color="g")
plt.plot(history.history["val_accuracy"],label="Test",color="r")
plt.show()

# %%
# epochs=list(range(200))
plt.plot(history.history["loss"],label="Train",color="g")
plt.plot(history.history["val_loss"],label="Test",color="r")
plt.show()
